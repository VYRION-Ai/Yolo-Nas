# %%
# !pip install -q super-gradients==3.1.1
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 964.2/964.2 kB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 17.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 684.5/684.5 kB 54.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 100.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 101.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.6/408.6 kB 45.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 108.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 21.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 75.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 82.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 15.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 63.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 81.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 88.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 64.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 81.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 121.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 113.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 72.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 16.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.0 MB/s eta 0:00:00
#   Building wheel for pycocotools (pyproject.toml) ... done
#   Building wheel for termcolor (setup.py) ... done
#   Building wheel for treelib (setup.py) ... done
#   Building wheel for coverage (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for stringcase (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.1+cu118 requires torch==2.0.0, but you have torch 1.13.1 which is incompatible.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 1.13.1 which is incompatible.
# torchtext 0.15.1 requires torch==2.0.0, but you have torch 1.13.1 which is incompatible.

# %% [markdown]
# ### 🚨 **Restart the runtime**
#
# ---
#
#
#
# **After installation is complete, you'll need to restart the runtime after installation completes. Navigate to `Runtime` -> `Restart runtime` and confirm by clicking `Yes` when you see the popup.**
#
# After that, carry on with the notebook starting from the cell below 👇

# %%
# !git clone https://github.com/VYRION-Ai/Yolo-Nas.git
# Out:
# Cloning into 'Yolo-Nas'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), 6.46 KiB | 2.15 MiB/s, done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/
# %cp /content/drive/MyDrive/Master/yolo_dataset.zip /content/
# !unzip  /content/yolo_dataset.zip
# !rm  /content/yolo_dataset.zip

# %%
# %cd /content/Yolo-Nas
# !python train.py --project "Dataset"  --data /content/Dataset/data.yaml --location '/content/Dataset' --model-arch yolo_nas_s --batch-size 16 --max-epochs 25 --checkpoint-dir /content/checkpoints
# Out:
# /content/Yolo-Nas
# The console stream is logged into /root/sg_logs/console.log
# [2023-05-13 13:29:05] INFO - crash_tips_setup.py - Crash tips is enabled. You can set your environment variable to CRASH_HANDLER=FALSE to disable it
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# [2023-05-13 13:29:11] WARNING - __init__.py - Failed to import pytorch_quantization
# [2023-05-13 13:29:11] WARNING - calibrator.py - Failed to import pytorch_quantization
# [2023-05-13 13:29:11] WARNING - export.py - Failed to import pytorch_quantization
# [2023-05-13 13:29:11] WARNING - selective_quantization_utils.py - Failed to import pytorch_quantization
# dataset_params {'data_dir': '/content/Dataset', 'train_images_dir': '/content/Dataset/images/train', 'train_labels_dir': '/content/Dataset/labels/train', 'val_images_dir': '/content/Dataset/images/valid', 'val_labels_dir': '/content/Dataset/labels/valid', 'test_images_dir': '/content/Dataset/images/test', 'test_labels_dir': '/content/Dataset/labels/test', 'classes': ['0']}
# Caching annotations: 100% 4208/4208 [00:00<00:00, 5205.18it/s]
# Caching annotations: 100% 1203/1203 [00:00<00:00, 5436.02it/s]
# Caching annotations: 100% 601/601 [00:00<00:00, 4806.01it/s]
# [2023-05-13 13:29:13] INFO - checkpoint_utils.py - License Notification: YOLO-NAS pre-trained weights are subjected to the specific license terms and conditions detailed in
# https://github.com/Deci-AI/super-gradients/blob/master/LICENSE.YOLONAS.md
# By downloading the pre-trained weight files you agree to comply with these terms.
# Downloading: "https://sghub.deci.ai/models/yolo_nas_s_coco.pth" to /root/.cache/torch/hub/checkpoints/yolo_nas_s_coco.pth
# 100% 73.1M/73.1M [00:01<00:00, 44.0MB/s]
# [2023-05-13 13:29:17] INFO - sg_trainer.py - Using EMA with params {'decay': 0.9, 'decay_type': 'threshold'}
# 2023-05-13 13:29:19.370550: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-13 13:29:21.450639: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [2023-05-13 13:29:23] INFO - utils.py - NumExpr defaulting to 2 threads.
# The console stream is now moved to /content/checkpoints/Dataset/console_May13_13_29_24.txt
# [2023-05-13 13:29:31] INFO - sg_trainer_utils.py - TRAINING PARAMETERS:
#     - Mode:                         Single GPU
#     - Number of GPUs:               1          (1 available on the machine)
#     - Dataset size:                 4208       (len(train_set))
#     - Batch size per GPU:           16         (batch_size)
#     - Batch Accumulate:             1          (batch_accumulate)
#     - Total batch size:             16         (num_gpus * batch_size)
#     - Effective Batch size:         16         (num_gpus * batch_size * batch_accumulate)
#     - Iterations per epoch:         263        (len(train_loader))
#     - Gradient updates per epoch:   263        (len(train_loader) / batch_accumulate)
#
# [2023-05-13 13:29:31] INFO - sg_trainer.py - Started training for 25 epochs (0/24)
#
# Train epoch 0: 100% 263/263 [04:41<00:00,  1.07s/it, PPYoloELoss/loss=3.82, PPYoloELoss/loss_cls=1.73, PPYoloELoss/loss_dfl=2.15, PPYoloELoss/loss_iou=0.404, gpu_mem=6.44]
# Validation epoch 0: 100% 76/76 [00:28<00:00,  2.69it/s]
# ===========================================================
# SUMMARY OF EPOCH 0
# ├── Training
# │   ├── Ppyoloeloss/loss = 3.8164
# │   ├── Ppyoloeloss/loss_cls = 1.7307
# │   ├── Ppyoloeloss/loss_dfl = 2.1517
# │   └── Ppyoloeloss/loss_iou = 0.4039
# └── Validation
#     ├── F1@0.50 = 0.0
#     ├── Map@0.50 = 0.0087
#     ├── Ppyoloeloss/loss = 3.6285
#     ├── Ppyoloeloss/loss_cls = 1.683
#     ├── Ppyoloeloss/loss_dfl = 2.123
#     ├── Ppyoloeloss/loss_iou = 0.3536
#     ├── Precision@0.50 = 0.0
#     └── Recall@0.50 = 0.0
#
# ===========================================================
# [2023-05-13 13:34:43] INFO - base_sg_logger.py - Checkpoint saved in /content/checkpoints/Dataset/ckpt_best.pth
# [2023-05-13 13:34:43] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.008733255788683891
# Train epoch 1: 100% 263/263 [04:36<00:00,  1.05s/it, PPYoloELoss/loss=2.94, PPYoloELoss/loss_cls=1.28, PPYoloELoss/loss_dfl=1.77, PPYoloELoss/loss_iou=0.309, gpu_mem=7.7]
# Validation epoch 1: 100% 76/76 [00:27<00:00,  2.79it/s]
# ===========================================================
# SUMMARY OF EPOCH 1
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.9426
# │   │   ├── Best until now = 3.8164 (↘ -0.8739)
# │   │   └── Epoch N-1      = 3.8164 (↘ -0.8739)
# │   ├── Ppyoloeloss/loss_cls = 1.2843
# │   │   ├── Best until now = 1.7307 (↘ -0.4464)
# │   │   └── Epoch N-1      = 1.7307 (↘ -0.4464)
# │   ├── Ppyoloeloss/loss_dfl = 1.7722
# │   │   ├── Best until now = 2.1517 (↘ -0.3795)
# │   │   └── Epoch N-1      = 2.1517 (↘ -0.3795)
# │   └── Ppyoloeloss/loss_iou = 0.3089
# │       ├── Best until now = 0.4039 (↘ -0.0951)
# │       └── Epoch N-1      = 0.4039 (↘ -0.0951)
# └── Validation
#     ├── F1@0.50 = 0.02
#     │   ├── Best until now = 0.0    (↗ 0.02)
#     │   └── Epoch N-1      = 0.0    (↗ 0.02)
#     ├── Map@0.50 = 0.2089
#     │   ├── Best until now = 0.0087 (↗ 0.2001)
#     │   └── Epoch N-1      = 0.0087 (↗ 0.2001)
#     ├── Ppyoloeloss/loss = 2.9102
#     │   ├── Best until now = 3.6285 (↘ -0.7184)
#     │   └── Epoch N-1      = 3.6285 (↘ -0.7184)
#     ├── Ppyoloeloss/loss_cls = 1.3183
#     │   ├── Best until now = 1.683  (↘ -0.3647)
#     │   └── Epoch N-1      = 1.683  (↘ -0.3647)
#     ├── Ppyoloeloss/loss_dfl = 1.7761
#     │   ├── Best until now = 2.123  (↘ -0.3468)
#     │   └── Epoch N-1      = 2.123  (↘ -0.3468)
#     ├── Ppyoloeloss/loss_iou = 0.2815
#     │   ├── Best until now = 0.3536 (↘ -0.0721)
#     │   └── Epoch N-1      = 0.3536 (↘ -0.0721)
#     ├── Precision@0.50 = 0.0101
#     │   ├── Best until now = 0.0    (↗ 0.0101)
#     │   └── Epoch N-1      = 0.0    (↗ 0.0101)
#     └── Recall@0.50 = 0.9443
#         ├── Best until now = 0.0    (↗ 0.9443)
#         └── Epoch N-1      = 0.0    (↗ 0.9443)
#
# ===========================================================
# [2023-05-13 13:39:55] INFO - base_sg_logger.py - Checkpoint saved in /content/checkpoints/Dataset/ckpt_best.pth
# [2023-05-13 13:39:55] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.20888276398181915
# Train epoch 2: 100% 263/263 [04:35<00:00,  1.05s/it, PPYoloELoss/loss=2.8, PPYoloELoss/loss_cls=1.27, PPYoloELoss/loss_dfl=1.67, PPYoloELoss/loss_iou=0.278, gpu_mem=7.7]
# Validation epoch 2: 100% 76/76 [00:26<00:00,  2.83it/s]
# ===========================================================
# SUMMARY OF EPOCH 2
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.796
# │   │   ├── Best until now = 2.9426 (↘ -0.1466)
# │   │   └── Epoch N-1      = 2.9426 (↘ -0.1466)
# │   ├── Ppyoloeloss/loss_cls = 1.2673
# │   │   ├── Best until now = 1.2843 (↘ -0.0171)
# │   │   └── Epoch N-1      = 1.2843 (↘ -0.0171)
# │   ├── Ppyoloeloss/loss_dfl = 1.6672
# │   │   ├── Best until now = 1.7722 (↘ -0.105)
# │   │   └── Epoch N-1      = 1.7722 (↘ -0.105)
# │   └── Ppyoloeloss/loss_iou = 0.2781
# │       ├── Best until now = 0.3089 (↘ -0.0308)
# │       └── Epoch N-1      = 0.3089 (↘ -0.0308)
# └── Validation
#     ├── F1@0.50 = 0.03
#     │   ├── Best until now = 0.02   (↗ 0.01)
#     │   └── Epoch N-1      = 0.02   (↗ 0.01)
#     ├── Map@0.50 = 0.1831
#     │   ├── Best until now = 0.2089 (↘ -0.0258)
#     │   └── Epoch N-1      = 0.2089 (↘ -0.0258)
#     ├── Ppyoloeloss/loss = 2.8116
#     │   ├── Best until now = 2.9102 (↘ -0.0985)
#     │   └── Epoch N-1      = 2.9102 (↘ -0.0985)
#     ├── Ppyoloeloss/loss_cls = 1.3107
#     │   ├── Best until now = 1.3183 (↘ -0.0076)
#     │   └── Epoch N-1      = 1.3183 (↘ -0.0076)
#     ├── Ppyoloeloss/loss_dfl = 1.6919
#     │   ├── Best until now = 1.7761 (↘ -0.0843)
#     │   └── Epoch N-1      = 1.7761 (↘ -0.0843)
#     ├── Ppyoloeloss/loss_iou = 0.262
#     │   ├── Best until now = 0.2815 (↘ -0.0195)
#     │   └── Epoch N-1      = 0.2815 (↘ -0.0195)
#     ├── Precision@0.50 = 0.0153
#     │   ├── Best until now = 0.0101 (↗ 0.0052)
#     │   └── Epoch N-1      = 0.0101 (↗ 0.0052)
#     └── Recall@0.50 = 0.926
#         ├── Best until now = 0.9443 (↘ -0.0182)
#         └── Epoch N-1      = 0.9443 (↘ -0.0182)
#
# ===========================================================
# Train epoch 3: 100% 263/263 [04:35<00:00,  1.05s/it, PPYoloELoss/loss=2.75, PPYoloELoss/loss_cls=1.26, PPYoloELoss/loss_dfl=1.64, PPYoloELoss/loss_iou=0.27, gpu_mem=7.7]
# Validation epoch 3: 100% 76/76 [00:27<00:00,  2.79it/s]
# ===========================================================
# SUMMARY OF EPOCH 3
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.7504
# │   │   ├── Best until now = 2.796  (↘ -0.0456)
# │   │   └── Epoch N-1      = 2.796  (↘ -0.0456)
# │   ├── Ppyoloeloss/loss_cls = 1.2569
# │   │   ├── Best until now = 1.2673 (↘ -0.0104)
# │   │   └── Epoch N-1      = 1.2673 (↘ -0.0104)
# │   ├── Ppyoloeloss/loss_dfl = 1.6359
# │   │   ├── Best until now = 1.6672 (↘ -0.0313)
# │   │   └── Epoch N-1      = 1.6672 (↘ -0.0313)
# │   └── Ppyoloeloss/loss_iou = 0.2702
# │       ├── Best until now = 0.2781 (↘ -0.0078)
# │       └── Epoch N-1      = 0.2781 (↘ -0.0078)
# └── Validation
#     ├── F1@0.50 = 0.0288
#     │   ├── Best until now = 0.03   (↘ -0.0013)
#     │   └── Epoch N-1      = 0.03   (↘ -0.0013)
#     ├── Map@0.50 = 0.176
#     │   ├── Best until now = 0.2089 (↘ -0.0328)
#     │   └── Epoch N-1      = 0.1831 (↘ -0.007)
#     ├── Ppyoloeloss/loss = 2.8469
#     │   ├── Best until now = 2.8116 (↗ 0.0352)
#     │   └── Epoch N-1      = 2.8116 (↗ 0.0352)
#     ├── Ppyoloeloss/loss_cls = 1.3189
#     │   ├── Best until now = 1.3107 (↗ 0.0082)
#     │   └── Epoch N-1      = 1.3107 (↗ 0.0082)
#     ├── Ppyoloeloss/loss_dfl = 1.7059
#     │   ├── Best until now = 1.6919 (↗ 0.014)
#     │   └── Epoch N-1      = 1.6919 (↗ 0.014)
#     ├── Ppyoloeloss/loss_iou = 0.27
#     │   ├── Best until now = 0.262  (↗ 0.008)
#     │   └── Epoch N-1      = 0.262  (↗ 0.008)
#     ├── Precision@0.50 = 0.0146
#     │   ├── Best until now = 0.0153 (↘ -0.0006)
#     │   └── Epoch N-1      = 0.0153 (↘ -0.0006)
#     └── Recall@0.50 = 0.8818
#         ├── Best until now = 0.9443 (↘ -0.0625)
#         └── Epoch N-1      = 0.926  (↘ -0.0443)
#
# ===========================================================
# Train epoch 4: 100% 263/263 [04:34<00:00,  1.04s/it, PPYoloELoss/loss=2.69, PPYoloELoss/loss_cls=1.25, PPYoloELoss/loss_dfl=1.58, PPYoloELoss/loss_iou=0.26, gpu_mem=7.7]
# Validation epoch 4: 100% 76/76 [00:28<00:00,  2.63it/s]
# ===========================================================
# SUMMARY OF EPOCH 4
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.6897
# │   │   ├── Best until now = 2.7504 (↘ -0.0607)
# │   │   └── Epoch N-1      = 2.7504 (↘ -0.0607)
# │   ├── Ppyoloeloss/loss_cls = 1.2482
# │   │   ├── Best until now = 1.2569 (↘ -0.0087)
# │   │   └── Epoch N-1      = 1.2569 (↘ -0.0087)
# │   ├── Ppyoloeloss/loss_dfl = 1.5813
# │   │   ├── Best until now = 1.6359 (↘ -0.0546)
# │   │   └── Epoch N-1      = 1.6359 (↘ -0.0546)
# │   └── Ppyoloeloss/loss_iou = 0.2603
# │       ├── Best until now = 0.2702 (↘ -0.0099)
# │       └── Epoch N-1      = 0.2702 (↘ -0.0099)
# └── Validation
#     ├── F1@0.50 = 0.0225
#     │   ├── Best until now = 0.03   (↘ -0.0075)
#     │   └── Epoch N-1      = 0.0288 (↘ -0.0062)
#     ├── Map@0.50 = 0.2958
#     │   ├── Best until now = 0.2089 (↗ 0.0869)
#     │   └── Epoch N-1      = 0.176  (↗ 0.1197)
#     ├── Ppyoloeloss/loss = 2.7406
#     │   ├── Best until now = 2.8116 (↘ -0.0711)
#     │   └── Epoch N-1      = 2.8469 (↘ -0.1063)
#     ├── Ppyoloeloss/loss_cls = 1.337
#     │   ├── Best until now = 1.3107 (↗ 0.0262)
#     │   └── Epoch N-1      = 1.3189 (↗ 0.0181)
#     ├── Ppyoloeloss/loss_dfl = 1.5914
#     │   ├── Best until now = 1.6919 (↘ -0.1005)
#     │   └── Epoch N-1      = 1.7059 (↘ -0.1144)
#     ├── Ppyoloeloss/loss_iou = 0.2432
#     │   ├── Best until now = 0.262  (↘ -0.0188)
#     │   └── Epoch N-1      = 0.27   (↘ -0.0268)
#     ├── Precision@0.50 = 0.0114
#     │   ├── Best until now = 0.0153 (↘ -0.0039)
#     │   └── Epoch N-1      = 0.0146 (↘ -0.0032)
#     └── Recall@0.50 = 0.9615
#         ├── Best until now = 0.9443 (↗ 0.0172)
#         └── Epoch N-1      = 0.8818 (↗ 0.0797)
#
# ===========================================================
# [2023-05-13 13:55:19] INFO - base_sg_logger.py - Checkpoint saved in /content/checkpoints/Dataset/ckpt_best.pth
# [2023-05-13 13:55:19] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.29575011134147644
# Train epoch 5: 100% 263/263 [04:33<00:00,  1.04s/it, PPYoloELoss/loss=2.66, PPYoloELoss/loss_cls=1.24, PPYoloELoss/loss_dfl=1.55, PPYoloELoss/loss_iou=0.257, gpu_mem=7.7]
# Validation epoch 5: 100% 76/76 [00:28<00:00,  2.64it/s]
# ===========================================================
# SUMMARY OF EPOCH 5
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.6621
# │   │   ├── Best until now = 2.6897 (↘ -0.0276)
# │   │   └── Epoch N-1      = 2.6897 (↘ -0.0276)
# │   ├── Ppyoloeloss/loss_cls = 1.2447
# │   │   ├── Best until now = 1.2482 (↘ -0.0035)
# │   │   └── Epoch N-1      = 1.2482 (↘ -0.0035)
# │   ├── Ppyoloeloss/loss_dfl = 1.5481
# │   │   ├── Best until now = 1.5813 (↘ -0.0332)
# │   │   └── Epoch N-1      = 1.5813 (↘ -0.0332)
# │   └── Ppyoloeloss/loss_iou = 0.2573
# │       ├── Best until now = 0.2603 (↘ -0.003)
# │       └── Epoch N-1      = 0.2603 (↘ -0.003)
# └── Validation
#     ├── F1@0.50 = 0.018
#     │   ├── Best until now = 0.03   (↘ -0.0121)
#     │   └── Epoch N-1      = 0.0225 (↘ -0.0046)
#     ├── Map@0.50 = 0.3361
#     │   ├── Best until now = 0.2958 (↗ 0.0404)
#     │   └── Epoch N-1      = 0.2958 (↗ 0.0404)
#     ├── Ppyoloeloss/loss = 2.7249
#     │   ├── Best until now = 2.7406 (↘ -0.0157)
#     │   └── Epoch N-1      = 2.7406 (↘ -0.0157)
#     ├── Ppyoloeloss/loss_cls = 1.3382
#     │   ├── Best until now = 1.3107 (↗ 0.0274)
#     │   └── Epoch N-1      = 1.337  (↗ 0.0012)
#     ├── Ppyoloeloss/loss_dfl = 1.5644
#     │   ├── Best until now = 1.5914 (↘ -0.0271)
#     │   └── Epoch N-1      = 1.5914 (↘ -0.0271)
#     ├── Ppyoloeloss/loss_iou = 0.2418
#     │   ├── Best until now = 0.2432 (↘ -0.0013)
#     │   └── Epoch N-1      = 0.2432 (↘ -0.0013)
#     ├── Precision@0.50 = 0.0091
#     │   ├── Best until now = 0.0153 (↘ -0.0062)
#     │   └── Epoch N-1      = 0.0114 (↘ -0.0023)
#     └── Recall@0.50 = 0.9833
#         ├── Best until now = 0.9615 (↗ 0.0219)
#         └── Epoch N-1      = 0.9615 (↗ 0.0219)
#
# ===========================================================
# [2023-05-13 14:00:33] INFO - base_sg_logger.py - Checkpoint saved in /content/checkpoints/Dataset/ckpt_best.pth
# [2023-05-13 14:00:33] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.3361493945121765
# Train epoch 6: 100% 263/263 [04:35<00:00,  1.05s/it, PPYoloELoss/loss=2.63, PPYoloELoss/loss_cls=1.24, PPYoloELoss/loss_dfl=1.53, PPYoloELoss/loss_iou=0.252, gpu_mem=7.7]
# Validation epoch 6: 100% 76/76 [00:28<00:00,  2.65it/s]
# ===========================================================
# SUMMARY OF EPOCH 6
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.6332
# │   │   ├── Best until now = 2.6621 (↘ -0.0289)
# │   │   └── Epoch N-1      = 2.6621 (↘ -0.0289)
# │   ├── Ppyoloeloss/loss_cls = 1.2393
# │   │   ├── Best until now = 1.2447 (↘ -0.0054)
# │   │   └── Epoch N-1      = 1.2447 (↘ -0.0054)
# │   ├── Ppyoloeloss/loss_dfl = 1.5264
# │   │   ├── Best until now = 1.5481 (↘ -0.0217)
# │   │   └── Epoch N-1      = 1.5481 (↘ -0.0217)
# │   └── Ppyoloeloss/loss_iou = 0.2523
# │       ├── Best until now = 0.2573 (↘ -0.005)
# │       └── Epoch N-1      = 0.2573 (↘ -0.005)
# └── Validation
#     ├── F1@0.50 = 0.0224
#     │   ├── Best until now = 0.03   (↘ -0.0077)
#     │   └── Epoch N-1      = 0.018  (↗ 0.0044)
#     ├── Map@0.50 = 0.332
#     │   ├── Best until now = 0.3361 (↘ -0.0042)
#     │   └── Epoch N-1      = 0.3361 (↘ -0.0042)
#     ├── Ppyoloeloss/loss = 2.7045
#     │   ├── Best until now = 2.7249 (↘ -0.0204)
#     │   └── Epoch N-1      = 2.7249 (↘ -0.0204)
#     ├── Ppyoloeloss/loss_cls = 1.3294
#     │   ├── Best until now = 1.3107 (↗ 0.0186)
#     │   └── Epoch N-1      = 1.3382 (↘ -0.0088)
#     ├── Ppyoloeloss/loss_dfl = 1.547
#     │   ├── Best until now = 1.5644 (↘ -0.0174)
#     │   └── Epoch N-1      = 1.5644 (↘ -0.0174)
#     ├── Ppyoloeloss/loss_iou = 0.2407
#     │   ├── Best until now = 0.2418 (↘ -0.0011)
#     │   └── Epoch N-1      = 0.2418 (↘ -0.0011)
#     ├── Precision@0.50 = 0.0113
#     │   ├── Best until now = 0.0153 (↘ -0.0039)
#     │   └── Epoch N-1      = 0.0091 (↗ 0.0022)
#     └── Recall@0.50 = 0.9609
#         ├── Best until now = 0.9833 (↘ -0.0224)
#         └── Epoch N-1      = 0.9833 (↘ -0.0224)
#
# ===========================================================
# Train epoch 7: 100% 263/263 [04:33<00:00,  1.04s/it, PPYoloELoss/loss=2.62, PPYoloELoss/loss_cls=1.23, PPYoloELoss/loss_dfl=1.51, PPYoloELoss/loss_iou=0.251, gpu_mem=7.7]
# Validation epoch 7: 100% 76/76 [00:27<00:00,  2.72it/s]
# ===========================================================
# SUMMARY OF EPOCH 7
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.6196
# │   │   ├── Best until now = 2.6332 (↘ -0.0136)
# │   │   └── Epoch N-1      = 2.6332 (↘ -0.0136)
# │   ├── Ppyoloeloss/loss_cls = 1.2347
# │   │   ├── Best until now = 1.2393 (↘ -0.0046)
# │   │   └── Epoch N-1      = 1.2393 (↘ -0.0046)
# │   ├── Ppyoloeloss/loss_dfl = 1.5131
# │   │   ├── Best until now = 1.5264 (↘ -0.0133)
# │   │   └── Epoch N-1      = 1.5264 (↘ -0.0133)
# │   └── Ppyoloeloss/loss_iou = 0.2514
# │       ├── Best until now = 0.2523 (↘ -0.0009)
# │       └── Epoch N-1      = 0.2523 (↘ -0.0009)
# └── Validation
#     ├── F1@0.50 = 0.0402
#     │   ├── Best until now = 0.03   (↗ 0.0101)
#     │   └── Epoch N-1      = 0.0224 (↗ 0.0178)
#     ├── Map@0.50 = 0.3784
#     │   ├── Best until now = 0.3361 (↗ 0.0423)
#     │   └── Epoch N-1      = 0.332  (↗ 0.0464)
#     ├── Ppyoloeloss/loss = 2.633
#     │   ├── Best until now = 2.7045 (↘ -0.0715)
#     │   └── Epoch N-1      = 2.7045 (↘ -0.0715)
#     ├── Ppyoloeloss/loss_cls = 1.2852
#     │   ├── Best until now = 1.3107 (↘ -0.0256)
#     │   └── Epoch N-1      = 1.3294 (↘ -0.0442)
#     ├── Ppyoloeloss/loss_dfl = 1.4971
#     │   ├── Best until now = 1.547  (↘ -0.0498)
#     │   └── Epoch N-1      = 1.547  (↘ -0.0498)
#     ├── Ppyoloeloss/loss_iou = 0.2397
#     │   ├── Best until now = 0.2407 (↘ -0.001)
#     │   └── Epoch N-1      = 0.2407 (↘ -0.001)
#     ├── Precision@0.50 = 0.0205
#     │   ├── Best until now = 0.0153 (↗ 0.0052)
#     │   └── Epoch N-1      = 0.0113 (↗ 0.0092)
#     └── Recall@0.50 = 0.9615
#         ├── Best until now = 0.9833 (↘ -0.0219)
#         └── Epoch N-1      = 0.9609 (↗ 0.0005)
#
# ===========================================================
# [2023-05-13 14:10:59] INFO - base_sg_logger.py - Checkpoint saved in /content/checkpoints/Dataset/ckpt_best.pth
# [2023-05-13 14:10:59] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.3784199059009552
# Train epoch 8: 100% 263/263 [04:36<00:00,  1.05s/it, PPYoloELoss/loss=2.61, PPYoloELoss/loss_cls=1.24, PPYoloELoss/loss_dfl=1.51, PPYoloELoss/loss_iou=0.248, gpu_mem=7.7]
# Validation epoch 8: 100% 76/76 [00:27<00:00,  2.81it/s]
# ===========================================================
# SUMMARY OF EPOCH 8
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.6115
# │   │   ├── Best until now = 2.6196 (↘ -0.0081)
# │   │   └── Epoch N-1      = 2.6196 (↘ -0.0081)
# │   ├── Ppyoloeloss/loss_cls = 1.238
# │   │   ├── Best until now = 1.2347 (↗ 0.0034)
# │   │   └── Epoch N-1      = 1.2347 (↗ 0.0034)
# │   ├── Ppyoloeloss/loss_dfl = 1.5062
# │   │   ├── Best until now = 1.5131 (↘ -0.0069)
# │   │   └── Epoch N-1      = 1.5131 (↘ -0.0069)
# │   └── Ppyoloeloss/loss_iou = 0.2481
# │       ├── Best until now = 0.2514 (↘ -0.0032)
# │       └── Epoch N-1      = 0.2514 (↘ -0.0032)
# └── Validation
#     ├── F1@0.50 = 0.0417
#     │   ├── Best until now = 0.0402 (↗ 0.0015)
#     │   └── Epoch N-1      = 0.0402 (↗ 0.0015)
#     ├── Map@0.50 = 0.3732
#     │   ├── Best until now = 0.3784 (↘ -0.0052)
#     │   └── Epoch N-1      = 0.3784 (↘ -0.0052)
#     ├── Ppyoloeloss/loss = 2.6013
#     │   ├── Best until now = 2.633  (↘ -0.0316)
#     │   └── Epoch N-1      = 2.633  (↘ -0.0316)
#     ├── Ppyoloeloss/loss_cls = 1.2469
#     │   ├── Best until now = 1.2852 (↘ -0.0383)
#     │   └── Epoch N-1      = 1.2852 (↘ -0.0383)
#     ├── Ppyoloeloss/loss_dfl = 1.507
#     │   ├── Best until now = 1.4971 (↗ 0.0099)
#     │   └── Epoch N-1      = 1.4971 (↗ 0.0099)
#     ├── Ppyoloeloss/loss_iou = 0.2404
#     │   ├── Best until now = 0.2397 (↗ 0.0007)
#     │   └── Epoch N-1      = 0.2397 (↗ 0.0007)
#     ├── Precision@0.50 = 0.0213
#     │   ├── Best until now = 0.0205 (↗ 0.0008)
#     │   └── Epoch N-1      = 0.0205 (↗ 0.0008)
#     └── Recall@0.50 = 0.9542
#         ├── Best until now = 0.9833 (↘ -0.0292)
#         └── Epoch N-1      = 0.9615 (↘ -0.0073)
#
# ===========================================================
# Train epoch 9: 100% 263/263 [04:33<00:00,  1.04s/it, PPYoloELoss/loss=2.6, PPYoloELoss/loss_cls=1.23, PPYoloELoss/loss_dfl=1.5, PPYoloELoss/loss_iou=0.247, gpu_mem=7.7]
# Validation epoch 9: 100% 76/76 [00:27<00:00,  2.80it/s]
# ===========================================================
# SUMMARY OF EPOCH 9
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.6003
# │   │   ├── Best until now = 2.6115 (↘ -0.0112)
# │   │   └── Epoch N-1      = 2.6115 (↘ -0.0112)
# │   ├── Ppyoloeloss/loss_cls = 1.2327
# │   │   ├── Best until now = 1.2347 (↘ -0.002)
# │   │   └── Epoch N-1      = 1.238  (↘ -0.0053)
# │   ├── Ppyoloeloss/loss_dfl = 1.5003
# │   │   ├── Best until now = 1.5062 (↘ -0.0059)
# │   │   └── Epoch N-1      = 1.5062 (↘ -0.0059)
# │   └── Ppyoloeloss/loss_iou = 0.247
# │       ├── Best until now = 0.2481 (↘ -0.0012)
# │       └── Epoch N-1      = 0.2481 (↘ -0.0012)
# └── Validation
#     ├── F1@0.50 = 0.0242
#     │   ├── Best until now = 0.0417 (↘ -0.0175)
#     │   └── Epoch N-1      = 0.0417 (↘ -0.0175)
#     ├── Map@0.50 = 0.3265
#     │   ├── Best until now = 0.3784 (↘ -0.0519)
#     │   └── Epoch N-1      = 0.3732 (↘ -0.0467)
#     ├── Ppyoloeloss/loss = 2.7083
#     │   ├── Best until now = 2.6013 (↗ 0.107)
#     │   └── Epoch N-1      = 2.6013 (↗ 0.107)
#     ├── Ppyoloeloss/loss_cls = 1.3441
#     │   ├── Best until now = 1.2469 (↗ 0.0972)
#     │   └── Epoch N-1      = 1.2469 (↗ 0.0972)
#     ├── Ppyoloeloss/loss_dfl = 1.5528
#     │   ├── Best until now = 1.4971 (↗ 0.0556)
#     │   └── Epoch N-1      = 1.507  (↗ 0.0458)
#     ├── Ppyoloeloss/loss_iou = 0.2351
#     │   ├── Best until now = 0.2397 (↘ -0.0046)
#     │   └── Epoch N-1      = 0.2404 (↘ -0.0053)
#     ├── Precision@0.50 = 0.0122
#     │   ├── Best until now = 0.0213 (↘ -0.0091)
#     │   └── Epoch N-1      = 0.0213 (↘ -0.0091)
#     └── Recall@0.50 = 0.9719
#         ├── Best until now = 0.9833 (↘ -0.0115)
#         └── Epoch N-1      = 0.9542 (↗ 0.0177)
#
# ===========================================================
# Train epoch 10: 100% 263/263 [04:28<00:00,  1.02s/it, PPYoloELoss/loss=2.58, PPYoloELoss/loss_cls=1.23, PPYoloELoss/loss_dfl=1.49, PPYoloELoss/loss_iou=0.244, gpu_mem=7.7]
# Validation epoch 10: 100% 76/76 [00:27<00:00,  2.74it/s]
# ===========================================================
# SUMMARY OF EPOCH 10
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.5845
# │   │   ├── Best until now = 2.6003 (↘ -0.0158)
# │   │   └── Epoch N-1      = 2.6003 (↘ -0.0158)
# │   ├── Ppyoloeloss/loss_cls = 1.2315
# │   │   ├── Best until now = 1.2327 (↘ -0.0012)
# │   │   └── Epoch N-1      = 1.2327 (↘ -0.0012)
# │   ├── Ppyoloeloss/loss_dfl = 1.4874
# │   │   ├── Best until now = 1.5003 (↘ -0.013)
# │   │   └── Epoch N-1      = 1.5003 (↘ -0.013)
# │   └── Ppyoloeloss/loss_iou = 0.2437
# │       ├── Best until now = 0.247  (↘ -0.0033)
# │       └── Epoch N-1      = 0.247  (↘ -0.0033)
# └── Validation
#     ├── F1@0.50 = 0.0455
#     │   ├── Best until now = 0.0417 (↗ 0.0038)
#     │   └── Epoch N-1      = 0.0242 (↗ 0.0213)
#     ├── Map@0.50 = 0.3465
#     │   ├── Best until now = 0.3784 (↘ -0.032)
#     │   └── Epoch N-1      = 0.3265 (↗ 0.0199)
#     ├── Ppyoloeloss/loss = 2.5892
#     │   ├── Best until now = 2.6013 (↘ -0.0122)
#     │   └── Epoch N-1      = 2.7083 (↘ -0.1191)
#     ├── Ppyoloeloss/loss_cls = 1.2436
#     │   ├── Best until now = 1.2469 (↘ -0.0032)
#     │   └── Epoch N-1      = 1.3441 (↘ -0.1005)
#     ├── Ppyoloeloss/loss_dfl = 1.5167
#     │   ├── Best until now = 1.4971 (↗ 0.0195)
#     │   └── Epoch N-1      = 1.5528 (↘ -0.0361)
#     ├── Ppyoloeloss/loss_iou = 0.2349
#     │   ├── Best until now = 0.2351 (↘ -0.0002)
#     │   └── Epoch N-1      = 0.2351 (↘ -0.0002)
#     ├── Precision@0.50 = 0.0233
#     │   ├── Best until now = 0.0213 (↗ 0.002)
#     │   └── Epoch N-1      = 0.0122 (↗ 0.0111)
#     └── Recall@0.50 = 0.9479
#         ├── Best until now = 0.9833 (↘ -0.0354)
#         └── Epoch N-1      = 0.9719 (↘ -0.024)
#
# ===========================================================
# Train epoch 11: 100% 263/263 [04:29<00:00,  1.03s/it, PPYoloELoss/loss=2.57, PPYoloELoss/loss_cls=1.23, PPYoloELoss/loss_dfl=1.48, PPYoloELoss/loss_iou=0.242, gpu_mem=7.7]
# Validation epoch 11: 100% 76/76 [00:28<00:00,  2.65it/s]
# ===========================================================
# SUMMARY OF EPOCH 11
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.571
# │   │   ├── Best until now = 2.5845 (↘ -0.0135)
# │   │   └── Epoch N-1      = 2.5845 (↘ -0.0135)
# │   ├── Ppyoloeloss/loss_cls = 1.2288
# │   │   ├── Best until now = 1.2315 (↘ -0.0027)
# │   │   └── Epoch N-1      = 1.2315 (↘ -0.0027)
# │   ├── Ppyoloeloss/loss_dfl = 1.475
# │   │   ├── Best until now = 1.4874 (↘ -0.0124)
# │   │   └── Epoch N-1      = 1.4874 (↘ -0.0124)
# │   └── Ppyoloeloss/loss_iou = 0.2419
# │       ├── Best until now = 0.2437 (↘ -0.0019)
# │       └── Epoch N-1      = 0.2437 (↘ -0.0019)
# └── Validation
#     ├── F1@0.50 = 0.0266
#     │   ├── Best until now = 0.0455 (↘ -0.0189)
#     │   └── Epoch N-1      = 0.0455 (↘ -0.0189)
#     ├── Map@0.50 = 0.3977
#     │   ├── Best until now = 0.3784 (↗ 0.0193)
#     │   └── Epoch N-1      = 0.3465 (↗ 0.0513)
#     ├── Ppyoloeloss/loss = 2.5978
#     │   ├── Best until now = 2.5892 (↗ 0.0086)
#     │   └── Epoch N-1      = 2.5892 (↗ 0.0086)
#     ├── Ppyoloeloss/loss_cls = 1.2667
#     │   ├── Best until now = 1.2436 (↗ 0.0231)
#     │   └── Epoch N-1      = 1.2436 (↗ 0.0231)
#     ├── Ppyoloeloss/loss_dfl = 1.4939
#     │   ├── Best until now = 1.4971 (↘ -0.0032)
#     │   └── Epoch N-1      = 1.5167 (↘ -0.0228)
#     ├── Ppyoloeloss/loss_iou = 0.2336
#     │   ├── Best until now = 0.2349 (↘ -0.0013)
#     │   └── Epoch N-1      = 0.2349 (↘ -0.0013)
#     ├── Precision@0.50 = 0.0135
#     │   ├── Best until now = 0.0233 (↘ -0.0098)
#     │   └── Epoch N-1      = 0.0233 (↘ -0.0098)
#     └── Recall@0.50 = 0.9714
#         ├── Best until now = 0.9833 (↘ -0.012)
#         └── Epoch N-1      = 0.9479 (↗ 0.0234)
#
# ===========================================================
# [2023-05-13 14:31:42] INFO - base_sg_logger.py - Checkpoint saved in /content/checkpoints/Dataset/ckpt_best.pth
# [2023-05-13 14:31:42] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.3977237045764923
# Train epoch 12: 100% 263/263 [04:31<00:00,  1.03s/it, PPYoloELoss/loss=2.56, PPYoloELoss/loss_cls=1.23, PPYoloELoss/loss_dfl=1.46, PPYoloELoss/loss_iou=0.241, gpu_mem=7.7]
# Validation epoch 12: 100% 76/76 [00:27<00:00,  2.72it/s]
# ===========================================================
# SUMMARY OF EPOCH 12
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.5577
# │   │   ├── Best until now = 2.571  (↘ -0.0132)
# │   │   └── Epoch N-1      = 2.571  (↘ -0.0132)
# │   ├── Ppyoloeloss/loss_cls = 1.2252
# │   │   ├── Best until now = 1.2288 (↘ -0.0036)
# │   │   └── Epoch N-1      = 1.2288 (↘ -0.0036)
# │   ├── Ppyoloeloss/loss_dfl = 1.4616
# │   │   ├── Best until now = 1.475  (↘ -0.0134)
# │   │   └── Epoch N-1      = 1.475  (↘ -0.0134)
# │   └── Ppyoloeloss/loss_iou = 0.2407
# │       ├── Best until now = 0.2419 (↘ -0.0012)
# │       └── Epoch N-1      = 0.2419 (↘ -0.0012)
# └── Validation
#     ├── F1@0.50 = 0.0277
#     │   ├── Best until now = 0.0455 (↘ -0.0178)
#     │   └── Epoch N-1      = 0.0266 (↗ 0.0011)
#     ├── Map@0.50 = 0.3296
#     │   ├── Best until now = 0.3977 (↘ -0.0681)
#     │   └── Epoch N-1      = 0.3977 (↘ -0.0681)
#     ├── Ppyoloeloss/loss = 2.6091
#     │   ├── Best until now = 2.5892 (↗ 0.0199)
#     │   └── Epoch N-1      = 2.5978 (↗ 0.0114)
#     ├── Ppyoloeloss/loss_cls = 1.2642
#     │   ├── Best until now = 1.2436 (↗ 0.0205)
#     │   └── Epoch N-1      = 1.2667 (↘ -0.0026)
#     ├── Ppyoloeloss/loss_dfl = 1.5054
#     │   ├── Best until now = 1.4939 (↗ 0.0115)
#     │   └── Epoch N-1      = 1.4939 (↗ 0.0115)
#     ├── Ppyoloeloss/loss_iou = 0.2369
#     │   ├── Best until now = 0.2336 (↗ 0.0033)
#     │   └── Epoch N-1      = 0.2336 (↗ 0.0033)
#     ├── Precision@0.50 = 0.014
#     │   ├── Best until now = 0.0233 (↘ -0.0093)
#     │   └── Epoch N-1      = 0.0135 (↗ 0.0005)
#     └── Recall@0.50 = 0.9781
#         ├── Best until now = 0.9833 (↘ -0.0052)
#         └── Epoch N-1      = 0.9714 (↗ 0.0068)
#
# ===========================================================
# Train epoch 13: 100% 263/263 [04:28<00:00,  1.02s/it, PPYoloELoss/loss=2.55, PPYoloELoss/loss_cls=1.23, PPYoloELoss/loss_dfl=1.45, PPYoloELoss/loss_iou=0.239, gpu_mem=7.7]
# Validation epoch 13: 100% 76/76 [00:28<00:00,  2.67it/s]
# ===========================================================
# SUMMARY OF EPOCH 13
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.5527
# │   │   ├── Best until now = 2.5577 (↘ -0.005)
# │   │   └── Epoch N-1      = 2.5577 (↘ -0.005)
# │   ├── Ppyoloeloss/loss_cls = 1.2279
# │   │   ├── Best until now = 1.2252 (↗ 0.0027)
# │   │   └── Epoch N-1      = 1.2252 (↗ 0.0027)
# │   ├── Ppyoloeloss/loss_dfl = 1.4542
# │   │   ├── Best until now = 1.4616 (↘ -0.0074)
# │   │   └── Epoch N-1      = 1.4616 (↘ -0.0074)
# │   └── Ppyoloeloss/loss_iou = 0.2391
# │       ├── Best until now = 0.2407 (↘ -0.0016)
# │       └── Epoch N-1      = 0.2407 (↘ -0.0016)
# └── Validation
#     ├── F1@0.50 = 0.0329
#     │   ├── Best until now = 0.0455 (↘ -0.0125)
#     │   └── Epoch N-1      = 0.0277 (↗ 0.0053)
#     ├── Map@0.50 = 0.3667
#     │   ├── Best until now = 0.3977 (↘ -0.031)
#     │   └── Epoch N-1      = 0.3296 (↗ 0.0371)
#     ├── Ppyoloeloss/loss = 2.6472
#     │   ├── Best until now = 2.5892 (↗ 0.0581)
#     │   └── Epoch N-1      = 2.6091 (↗ 0.0381)
#     ├── Ppyoloeloss/loss_cls = 1.2623
#     │   ├── Best until now = 1.2436 (↗ 0.0187)
#     │   └── Epoch N-1      = 1.2642 (↘ -0.0019)
#     ├── Ppyoloeloss/loss_dfl = 1.563
#     │   ├── Best until now = 1.4939 (↗ 0.069)
#     │   └── Epoch N-1      = 1.5054 (↗ 0.0575)
#     ├── Ppyoloeloss/loss_iou = 0.2414
#     │   ├── Best until now = 0.2336 (↗ 0.0078)
#     │   └── Epoch N-1      = 0.2369 (↗ 0.0045)
#     ├── Precision@0.50 = 0.0168
#     │   ├── Best until now = 0.0233 (↘ -0.0065)
#     │   └── Epoch N-1      = 0.014  (↗ 0.0027)
#     └── Recall@0.50 = 0.9677
#         ├── Best until now = 0.9833 (↘ -0.0156)
#         └── Epoch N-1      = 0.9781 (↘ -0.0104)
#
# ===========================================================
# Train epoch 14: 100% 263/263 [04:32<00:00,  1.04s/it, PPYoloELoss/loss=2.53, PPYoloELoss/loss_cls=1.22, PPYoloELoss/loss_dfl=1.43, PPYoloELoss/loss_iou=0.237, gpu_mem=7.7]
# Validation epoch 14: 100% 76/76 [00:27<00:00,  2.72it/s]
# ===========================================================
# SUMMARY OF EPOCH 14
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.5332
# │   │   ├── Best until now = 2.5527 (↘ -0.0195)
# │   │   └── Epoch N-1      = 2.5527 (↘ -0.0195)
# │   ├── Ppyoloeloss/loss_cls = 1.2237
# │   │   ├── Best until now = 1.2252 (↘ -0.0015)
# │   │   └── Epoch N-1      = 1.2279 (↘ -0.0042)
# │   ├── Ppyoloeloss/loss_dfl = 1.4336
# │   │   ├── Best until now = 1.4542 (↘ -0.0207)
# │   │   └── Epoch N-1      = 1.4542 (↘ -0.0207)
# │   └── Ppyoloeloss/loss_iou = 0.2371
# │       ├── Best until now = 0.2391 (↘ -0.002)
# │       └── Epoch N-1      = 0.2391 (↘ -0.002)
# └── Validation
#     ├── F1@0.50 = 0.0606
#     │   ├── Best until now = 0.0455 (↗ 0.0151)
#     │   └── Epoch N-1      = 0.0329 (↗ 0.0277)
#     ├── Map@0.50 = 0.3521
#     │   ├── Best until now = 0.3977 (↘ -0.0457)
#     │   └── Epoch N-1      = 0.3667 (↘ -0.0147)
#     ├── Ppyoloeloss/loss = 2.5712
#     │   ├── Best until now = 2.5892 (↘ -0.018)
#     │   └── Epoch N-1      = 2.6472 (↘ -0.0761)
#     ├── Ppyoloeloss/loss_cls = 1.2501
#     │   ├── Best until now = 1.2436 (↗ 0.0065)
#     │   └── Epoch N-1      = 1.2623 (↘ -0.0122)
#     ├── Ppyoloeloss/loss_dfl = 1.4883
#     │   ├── Best until now = 1.4939 (↘ -0.0056)
#     │   └── Epoch N-1      = 1.563  (↘ -0.0747)
#     ├── Ppyoloeloss/loss_iou = 0.2307
#     │   ├── Best until now = 0.2336 (↘ -0.0029)
#     │   └── Epoch N-1      = 0.2414 (↘ -0.0106)
#     ├── Precision@0.50 = 0.0313
#     │   ├── Best until now = 0.0233 (↗ 0.008)
#     │   └── Epoch N-1      = 0.0168 (↗ 0.0146)
#     └── Recall@0.50 = 0.9365
#         ├── Best until now = 0.9833 (↘ -0.0469)
#         └── Epoch N-1      = 0.9677 (↘ -0.0312)
#
# ===========================================================
# Train epoch 15: 100% 263/263 [04:31<00:00,  1.03s/it, PPYoloELoss/loss=2.53, PPYoloELoss/loss_cls=1.22, PPYoloELoss/loss_dfl=1.43, PPYoloELoss/loss_iou=0.235, gpu_mem=7.7]
# Validation epoch 15: 100% 76/76 [00:28<00:00,  2.63it/s]
# ===========================================================
# SUMMARY OF EPOCH 15
# ├── Training
# │   ├── Ppyoloeloss/loss = 2.527
# │   │   ├── Best until now = 2.5332 (↘ -0.0062)
# │   │   └── Epoch N-1      = 2.5332 (↘ -0.0062)
# │   ├── Ppyoloeloss/loss_cls = 1.2226
# │   │   ├── Best until now = 1.2237 (↘ -0.0011)
# │   │   └── Epoch N-1      = 1.2237 (↘ -0.0011)
# │   ├── Ppyoloeloss/loss_dfl = 1.4344
# │   │   ├── Best until now = 1.4336 (↗ 0.0008)
# │   │   └── Epoch N-1      = 1.4336 (↗ 0.0008)
# │   └── Ppyoloeloss/loss_iou = 0.2349
# │       ├── Best until now = 0.2371 (↘ -0.0022)
# │       └── Epoch N-1      = 0.2371 (↘ -0.0022)
# └── Validation
#     ├── F1@0.50 = 0.0445
#     │   ├── Best until now = 0.0606 (↘ -0.0161)
#     │   └── Epoch N-1      = 0.0606 (↘ -0.0161)
#     ├── Map@0.50 = 0.4299
#     │   ├── Best until now = 0.3977 (↗ 0.0321)
#     │   └── Epoch N-1      = 0.3521 (↗ 0.0778)
#     ├── Ppyoloeloss/loss = 2.5697
#     │   ├── Best until now = 2.5712 (↘ -0.0015)
#     │   └── Epoch N-1      = 2.5712 (↘ -0.0015)
#     ├── Ppyoloeloss/loss_cls = 1.2678
#     │   ├── Best until now = 1.2436 (↗ 0.0242)
#     │   └── Epoch N-1      = 1.2501 (↗ 0.0177)
#     ├── Ppyoloeloss/loss_dfl = 1.4763
#     │   ├── Best until now = 1.4883 (↘ -0.012)
#     │   └── Epoch N-1      = 1.4883 (↘ -0.012)
#     ├── Ppyoloeloss/loss_iou = 0.2255
#     │   ├── Best until now = 0.2307 (↘ -0.0053)
#     │   └── Epoch N-1      = 0.2307 (↘ -0.0053)
#     ├── Precision@0.50 = 0.0228
#     │   ├── Best until now = 0.0313 (↘ -0.0085)
#     │   └── Epoch N-1      = 0.0313 (↘ -0.0085)
#     └── Recall@0.50 = 0.9552
#         ├── Best until now = 0.9833 (↘ -0.0281)
#         └── Epoch N-1      = 0.9365 (↗ 0.0188)
#
# ===========================================================
# [2023-05-13 14:52:22] INFO - base_sg_logger.py - Checkpoint saved in /content/checkpoints/Dataset/ckpt_best.pth
# [2023-05-13 14:52:22] INFO - sg_trainer.py - Best checkpoint overriden: validation mAP@0.50: 0.429867684841156
# Train epoch 16:  89% 234/263 [04:02<00:35,  1.21s/it, PPYoloELoss/loss=2.52, PPYoloELoss/loss_cls=1.22, PPYoloELoss/loss_dfl=1.43, PPYoloELoss/loss_iou=0.233, gpu_mem=7.7]
